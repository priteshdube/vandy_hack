# %%
import pandas as pd

# Define enhanced dataset
data = [
    {
        "Country": "China",
        "Tariff Imposed by US (%)": 54,
        "Top Product Categories": "Electronics, Apparel, Toys",
        "Specific Product Names": "Apple iPhones, Lenovo laptops, Nike shoes, Mattel toys",
        "Estimated Annual Import Value (Billion USD)": 500,
        "Alternative Suppliers": "Vietnam, South Korea, India",
        "Use Case Impact": "Consumer electronics, daily clothing, children's goods"
    },
    {
        "Country": "Mexico",
        "Tariff Imposed by US (%)": 25,
        "Top Product Categories": "Vehicles, Electronics, Agricultural Products",
        "Specific Product Names": "Ford Mustang, Samsung TVs, avocados",
        "Estimated Annual Import Value (Billion USD)": 475.6,
        "Alternative Suppliers": "Canada, Japan, Brazil",
        "Use Case Impact": "Automotive industry, consumer electronics, food supply"
    },
    {
        "Country": "Canada",
        "Tariff Imposed by US (%)": 25,
        "Top Product Categories": "Oil, Vehicles, Timber",
        "Specific Product Names": "Crude oil (10% tariff), Toyota Camry, lumber",
        "Estimated Annual Import Value (Billion USD)": 421,
        "Alternative Suppliers": "Mexico, Norway, Russia",
        "Use Case Impact": "Energy sector, automotive manufacturing, construction"
    },
    {
        "Country": "Germany",
        "Tariff Imposed by US (%)": 10,
        "Top Product Categories": "Vehicles, Machinery, Pharmaceuticals",
        "Specific Product Names": "BMW X5, Bosch drills, Bayer Aspirin",
        "Estimated Annual Import Value (Billion USD)": 160,
        "Alternative Suppliers": "Japan, South Korea, France",
        "Use Case Impact": "Luxury cars, industrial tools, healthcare"
    },
    {
        "Country": "Japan",
        "Tariff Imposed by US (%)": 10,
        "Top Product Categories": "Vehicles, Electronics, Machinery",
        "Specific Product Names": "Toyota Prius, Sony TVs, Honda engines",
        "Estimated Annual Import Value (Billion USD)": 147,
        "Alternative Suppliers": "South Korea, Germany, Mexico",
        "Use Case Impact": "Automotive, consumer electronics, manufacturing"
    },
    {
        "Country": "South Korea",
        "Tariff Imposed by US (%)": 10,
        "Top Product Categories": "Vehicles, Electronics, Steel",
        "Specific Product Names": "Hyundai Sonata, Samsung Galaxy, POSCO steel",
        "Estimated Annual Import Value (Billion USD)": 116,
        "Alternative Suppliers": "Japan, China, Germany",
        "Use Case Impact": "Automotive, smartphones, construction materials"
    },
    {
        "Country": "Vietnam",
        "Tariff Imposed by US (%)": 46,  # Updated from 10%; Newsweek and Al Jazeera report 46% reciprocal tariff
        "Top Product Categories": "Apparel, Electronics, Footwear",
        "Specific Product Names": "H&M shirts, Foxconn cables, Adidas sneakers",
        "Estimated Annual Import Value (Billion USD)": 114,
        "Alternative Suppliers": "China, Bangladesh, India",
        "Use Case Impact": "Fashion, tech components, casual footwear"
    },
    {
        "Country": "India",
        "Tariff Imposed by US (%)": 26,  # Updated from 2.5%; AS USA and X posts report 26%
        "Top Product Categories": "Pharmaceuticals, Textiles, Jewelry",
        "Specific Product Names": "Generic drugs, cotton sarees, diamond rings",
        "Estimated Annual Import Value (Billion USD)": 84,
        "Alternative Suppliers": "Ireland, Pakistan, Israel",
        "Use Case Impact": "Healthcare, clothing, luxury goods"
    },
    {
        "Country": "Ireland",
        "Tariff Imposed by US (%)": 20,  # Updated from 0%; EU-wide 20% tariff per Newsweek and BBC
        "Top Product Categories": "Pharmaceuticals, Electronics, Beverages",
        "Specific Product Names": "Pfizer vaccines, Intel chips, Guinness beer",
        "Estimated Annual Import Value (Billion USD)": 82,
        "Alternative Suppliers": "Germany, UK, Switzerland",
        "Use Case Impact": "Medical treatments, tech hardware, alcohol"
    },
    {
        "Country": "Italy",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff per Newsweek and BBC
        "Top Product Categories": "Machinery, Fashion, Food",
        "Specific Product Names": "Fiat engines, Gucci bags, Barilla pasta",
        "Estimated Annual Import Value (Billion USD)": 73,
        "Alternative Suppliers": "France, Spain, Germany",
        "Use Case Impact": "Industrial parts, luxury fashion, cuisine"
    },
    {
        "Country": "Taiwan",
        "Tariff Imposed by US (%)": 32,  # Updated from 5%; Newsweek, Al Jazeera, and TIME report 32%
        "Top Product Categories": "Electronics, Machinery, Plastics",
        "Specific Product Names": "TSMC chips, Acer laptops, PVC pipes",
        "Estimated Annual Import Value (Billion USD)": 70,
        "Alternative Suppliers": "South Korea, Japan, China",
        "Use Case Impact": "Tech hardware, manufacturing, construction"
    },
    {
        "Country": "Switzerland",
        "Tariff Imposed by US (%)": 31,  # Updated from 2%; AS USA and X posts report 31-32%, using 31% as consistent
        "Top Product Categories": "Pharmaceuticals, Watches, Machinery",
        "Specific Product Names": "Novartis drugs, Rolex watches, CNC machines",
        "Estimated Annual Import Value (Billion USD)": 65,
        "Alternative Suppliers": "Germany, Ireland, France",
        "Use Case Impact": "Healthcare, luxury goods, industrial tools"
    },
    {
        "Country": "United Kingdom",
        "Tariff Imposed by US (%)": 10,  # Updated from 2%; AS USA and The Independent report 10% baseline
        "Top Product Categories": "Machinery, Pharmaceuticals, Beverages",
        "Specific Product Names": "Rolls-Royce engines, AstraZeneca vaccines, Scotch whisky",
        "Estimated Annual Import Value (Billion USD)": 62,
        "Alternative Suppliers": "Germany, Ireland, Canada",
        "Use Case Impact": "Aerospace, medicine, alcohol"
    },
    {
        "Country": "France",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff per Newsweek and BBC
        "Top Product Categories": "Wine, Machinery, Cosmetics",
        "Specific Product Names": "Bordeaux wine, Airbus parts, L’Oréal creams",
        "Estimated Annual Import Value (Billion USD)": 58,
        "Alternative Suppliers": "Italy, Spain, Germany",
        "Use Case Impact": "Beverages, aviation, beauty products"
    },
    {
        "Country": "Thailand",
        "Tariff Imposed by US (%)": 36,  # Updated from 4%; TIME and AS USA report 36-37%, using 36% as consistent
        "Top Product Categories": "Electronics, Rubber, Food",
        "Specific Product Names": "Western Digital drives, Goodyear tires, Thai rice",
        "Estimated Annual Import Value (Billion USD)": 50,
        "Alternative Suppliers": "Vietnam, Malaysia, Indonesia",
        "Use Case Impact": "Tech storage, automotive, food supply"
    },
    {
        "Country": "Malaysia",
        "Tariff Imposed by US (%)": 24,  # Updated from 3%; Al Jazeera and Reuters report 24%
        "Top Product Categories": "Electronics, Rubber, Oil",
        "Specific Product Names": "Intel processors, latex gloves, palm oil",
        "Estimated Annual Import Value (Billion USD)": 48,
        "Alternative Suppliers": "Thailand, Vietnam, Indonesia",
        "Use Case Impact": "Tech components, medical supplies, cooking oil"
    },
    {
        "Country": "Netherlands",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff (Newsweek, BBC)
        "Top Product Categories": "Machinery, Chemicals, Oil",
        "Specific Product Names": "Philips scanners, Shell lubricants, crude oil",
        "Estimated Annual Import Value (Billion USD)": 45,
        "Alternative Suppliers": "Germany, Belgium, UK",
        "Use Case Impact": "Medical equipment, industrial fluids, energy"
    },
    {
        "Country": "Singapore",
        "Tariff Imposed by US (%)": 10,  # Updated from 0%; 10% baseline tariff (Al Jazeera, TIME)
        "Top Product Categories": "Electronics, Chemicals, Machinery",
        "Specific Product Names": "Seagate drives, Dow chemicals, precision tools",
        "Estimated Annual Import Value (Billion USD)": 42,
        "Alternative Suppliers": "Malaysia, Taiwan, Japan",
        "Use Case Impact": "Data storage, manufacturing, industrial tools"
    },
    {
        "Country": "Brazil",
        "Tariff Imposed by US (%)": 10,  # Updated from 2.5%; 10% baseline tariff (Al Jazeera, Reuters)
        "Top Product Categories": "Oil, Agricultural Products, Aircraft",
        "Specific Product Names": "Petrobras crude, soybeans, Embraer jets",
        "Estimated Annual Import Value (Billion USD)": 40,
        "Alternative Suppliers": "Canada, Argentina, Mexico",
        "Use Case Impact": "Energy, food supply, aviation"
    },
    {
        "Country": "Indonesia",
        "Tariff Imposed by US (%)": 35,  # Updated from 5%; AS USA and X posts report 35%
        "Top Product Categories": "Apparel, Rubber, Oil",
        "Specific Product Names": "Gap shirts, Bridgestone tires, palm oil",
        "Estimated Annual Import Value (Billion USD)": 38,
        "Alternative Suppliers": "Vietnam, Thailand, Malaysia",
        "Use Case Impact": "Clothing, automotive, food products"
    },
    {
        "Country": "Spain",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff (Newsweek, BBC)
        "Top Product Categories": "Wine, Machinery, Olive Oil",
        "Specific Product Names": "Rioja wine, CNC lathes, Bertolli olive oil",
        "Estimated Annual Import Value (Billion USD)": 35,
        "Alternative Suppliers": "Italy, France, Portugal",
        "Use Case Impact": "Beverages, manufacturing, cooking"
    },
    {
        "Country": "Belgium",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff (Newsweek, BBC)
        "Top Product Categories": "Chemicals, Machinery, Diamonds",
        "Specific Product Names": "BASF chemicals, milling machines, loose diamonds",
        "Estimated Annual Import Value (Billion USD)": 33,
        "Alternative Suppliers": "Germany, Netherlands, India",
        "Use Case Impact": "Industrial chemicals, tools, jewelry"
    },
    {
        "Country": "Israel",
        "Tariff Imposed by US (%)": 17,  # Updated from 0%; Reuters and TIME report 17%
        "Top Product Categories": "Pharmaceuticals, Electronics, Diamonds",
        "Specific Product Names": "Teva generics, Intel chips, polished diamonds",
        "Estimated Annual Import Value (Billion USD)": 30,
        "Alternative Suppliers": "Ireland, India, Belgium",
        "Use Case Impact": "Healthcare, tech, luxury goods"
    },
    {
        "Country": "Philippines",
        "Tariff Imposed by US (%)": 18,  # Updated from 3%; Al Jazeera and TIME report 18%
        "Top Product Categories": "Electronics, Apparel, Food",
        "Specific Product Names": "Toshiba chips, Uniqlo shirts, bananas",
        "Estimated Annual Import Value (Billion USD)": 28,
        "Alternative Suppliers": "Vietnam, Thailand, Indonesia",
        "Use Case Impact": "Tech components, fashion, food supply"
    },
    {
        "Country": "Australia",
        "Tariff Imposed by US (%)": 10,  # Updated from 0%; 10% baseline tariff (Al Jazeera, CBS News)
        "Top Product Categories": "Meat, Minerals, Wine",
        "Specific Product Names": "Angus beef, iron ore, Penfolds wine",
        "Estimated Annual Import Value (Billion USD)": 26,
        "Alternative Suppliers": "New Zealand, Canada, Chile",
        "Use Case Impact": "Food industry, construction, beverages"
    },
    {
        "Country": "Russia",
        "Tariff Imposed by US (%)": 35,  # Unchanged; high tariffs/sanctions predate 2025 (AS USA, Independent)
        "Top Product Categories": "Oil, Metals, Fertilizers",
        "Specific Product Names": "Crude oil, aluminum, urea",
        "Estimated Annual Import Value (Billion USD)": 25,
        "Alternative Suppliers": "Canada, Brazil, Norway",
        "Use Case Impact": "Energy, manufacturing, agriculture"
    },
    {
        "Country": "Saudi Arabia",
        "Tariff Imposed by US (%)": 10,  # Updated from 2%; 10% baseline tariff (Al Jazeera, Independent)
        "Top Product Categories": "Oil, Chemicals, Plastics",
        "Specific Product Names": "Aramco crude, petrochemicals, polyethylene",
        "Estimated Annual Import Value (Billion USD)": 24,
        "Alternative Suppliers": "Canada, Russia, UAE",
        "Use Case Impact": "Energy, industrial materials, packaging"
    },
    {
        "Country": "Poland",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff (Newsweek, BBC)
        "Top Product Categories": "Machinery, Furniture, Electronics",
        "Specific Product Names": "CNC machines, IKEA chairs, LG TVs",
        "Estimated Annual Import Value (Billion USD)": 22,
        "Alternative Suppliers": "Germany, Czech Republic, Sweden",
        "Use Case Impact": "Manufacturing, home goods, tech"
    },
    {
        "Country": "Turkey",
        "Tariff Imposed by US (%)": 25,  # Updated from 10%; Al Jazeera and AS USA report 25%
        "Top Product Categories": "Textiles, Machinery, Steel",
        "Specific Product Names": "Denim jeans, lathes, rebar",
        "Estimated Annual Import Value (Billion USD)": 21,
        "Alternative Suppliers": "India, Italy, China",
        "Use Case Impact": "Fashion, industrial tools, construction"
    },
    {
        "Country": "Sweden",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff (Newsweek, BBC)
        "Top Product Categories": "Machinery, Vehicles, Furniture",
        "Specific Product Names": "Volvo trucks, IKEA tables, lathes",
        "Estimated Annual Import Value (Billion USD)": 20,
        "Alternative Suppliers": "Germany, Norway, Finland",
        "Use Case Impact": "Transportation, home goods, manufacturing"
    },
    {
        "Country": "Norway",
        "Tariff Imposed by US (%)": 15,  # Updated from 2%; TIME and NRK report 15%
        "Top Product Categories": "Oil, Fish, Machinery",
        "Specific Product Names": "Statoil crude, salmon, drilling rigs",
        "Estimated Annual Import Value (Billion USD)": 19,
        "Alternative Suppliers": "Canada, Russia, Iceland",
        "Use Case Impact": "Energy, seafood, industrial equipment"
    },
    {
        "Country": "Czech Republic",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff (Newsweek, BBC)
        "Top Product Categories": "Vehicles, Machinery, Electronics",
        "Specific Product Names": "Skoda cars, milling machines, Foxconn parts",
        "Estimated Annual Import Value (Billion USD)": 18,
        "Alternative Suppliers": "Germany, Poland, Slovakia",
        "Use Case Impact": "Automotive, manufacturing, tech"
    },
    {
        "Country": "Austria",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff (Newsweek, BBC)
        "Top Product Categories": "Machinery, Metals, Pharmaceuticals",
        "Specific Product Names": "Voestalpine steel, Red Bull, generic drugs",
        "Estimated Annual Import Value (Billion USD)": 17,
        "Alternative Suppliers": "Germany, Switzerland, Italy",
        "Use Case Impact": "Industrial materials, energy drinks, healthcare"
    },
    {
        "Country": "Denmark",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff (Newsweek, BBC)
        "Top Product Categories": "Pharmaceuticals, Machinery, Food",
        "Specific Product Names": "Novo Nordisk insulin, wind turbines, Danish butter",
        "Estimated Annual Import Value (Billion USD)": 16,
        "Alternative Suppliers": "Germany, Sweden, Ireland",
        "Use Case Impact": "Healthcare, renewable energy, food"
    },
    {
        "Country": "Hungary",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff (Newsweek, BBC)
        "Top Product Categories": "Vehicles, Electronics, Machinery",
        "Specific Product Names": "Audi Q3, Nokia parts, lathes",
        "Estimated Annual Import Value (Billion USD)": 15,
        "Alternative Suppliers": "Germany, Czech Republic, Poland",
        "Use Case Impact": "Automotive, tech components, manufacturing"
    },
    {
        "Country": "Finland",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff (Newsweek, BBC)
        "Top Product Categories": "Machinery, Paper, Electronics",
        "Specific Product Names": "Kone elevators, UPM paper, Nokia routers",
        "Estimated Annual Import Value (Billion USD)": 14,
        "Alternative Suppliers": "Sweden, Germany, Estonia",
        "Use Case Impact": "Industrial equipment, packaging, tech"
    },
    {
        "Country": "Portugal",
        "Tariff Imposed by US (%)": 20,  # Updated from 2%; EU-wide 20% tariff (Newsweek, BBC)
        "Top Product Categories": "Textiles, Wine, Machinery",
        "Specific Product Names": "Zara shirts, Port wine, textile looms",
        "Estimated Annual Import Value (Billion USD)": 13,
        "Alternative Suppliers": "Spain, Italy, France",
        "Use Case Impact": "Fashion, beverages, manufacturing"
    },
    {
        "Country": "South Africa",
        "Tariff Imposed by US (%)": 15,  # Updated from 2.5%; AS USA and CNBC report 15%
        "Top Product Categories": "Metals, Agricultural Products, Diamonds",
        "Specific Product Names": "Platinum, oranges, rough diamonds",
        "Estimated Annual Import Value (Billion USD)": 12,
        "Alternative Suppliers": "Australia, Brazil, Botswana",
        "Use Case Impact": "Industrial materials, food, jewelry"
    },
    {
        "Country": "Chile",
        "Tariff Imposed by US (%)": 10,  # Updated from 0%; 10% baseline tariff (Al Jazeera, Reuters)
        "Top Product Categories": "Copper, Fruit, Wine",
        "Specific Product Names": "Copper cathodes, grapes, Concha y Toro wine",
        "Estimated Annual Import Value (Billion USD)": 11,
        "Alternative Suppliers": "Peru, Argentina, Australia",
        "Use Case Impact": "Electronics, food supply, beverages"
    },
    {
        "Country": "Argentina",
        "Tariff Imposed by US (%)": 10,  # Updated from 2.5%; 10% baseline tariff (Al Jazeera, Reuters)
        "Top Product Categories": "Agricultural Products, Oil, Wine",
        "Specific Product Names": "Soybeans, crude oil, Malbec wine",
        "Estimated Annual Import Value (Billion USD)": 10,
        "Alternative Suppliers": "Brazil, Chile, Canada",
        "Use Case Impact": "Food industry, energy, beverages"
    },
    {
        "Country": "United Arab Emirates",
        "Tariff Imposed by US (%)": 10,  # Updated from 2%; 10% baseline tariff (Al Jazeera, Gulf Business)
        "Top Product Categories": "Oil, Aluminum, Jewelry",
        "Specific Product Names": "Crude oil, aluminum sheets, gold necklaces",
        "Estimated Annual Import Value (Billion USD)": 9,
        "Alternative Suppliers": "Saudi Arabia, Russia, India",
        "Use Case Impact": "Energy, construction, luxury goods"
    },
    {
        "Country": "New Zealand",
        "Tariff Imposed by US (%)": 10,  # Updated from 0%; 10% baseline tariff (Hindustan Times, The Daily Star)
        "Top Product Categories": "Dairy, Meat, Wine",
        "Specific Product Names": "Fonterra milk, lamb, Sauvignon Blanc",
        "Estimated Annual Import Value (Billion USD)": 8,
        "Alternative Suppliers": "Australia, Ireland, Chile",
        "Use Case Impact": "Food industry, beverages"
    },
    {
        "Country": "Colombia",
        "Tariff Imposed by US (%)": 10,  # Updated from 0%; 10% baseline tariff (TIME, Hindustan Times)
        "Top Product Categories": "Coffee, Oil, Flowers",
        "Specific Product Names": "Juan Valdez coffee, crude oil, roses",
        "Estimated Annual Import Value (Billion USD)": 7,
        "Alternative Suppliers": "Brazil, Ecuador, Venezuela",
        "Use Case Impact": "Beverages, energy, floral arrangements"
    },
    {
        "Country": "Pakistan",
        "Tariff Imposed by US (%)": 29,  # Updated from 5%; AS USA and Hindustan Times report 29%
        "Top Product Categories": "Textiles, Surgical Instruments, Rice",
        "Specific Product Names": "Cotton towels, scalpels, basmati rice",
        "Estimated Annual Import Value (Billion USD)": 6,
        "Alternative Suppliers": "India, Bangladesh, Vietnam",
        "Use Case Impact": "Clothing, medical tools, food"
    },
    {
        "Country": "Egypt",
        "Tariff Imposed by US (%)": 10,  # Updated from 3%; 10% baseline tariff (Middle East Eye, Hindustan Times)
        "Top Product Categories": "Textiles, Agricultural Products, Chemicals",
        "Specific Product Names": "Cotton shirts, oranges, fertilizers",
        "Estimated Annual Import Value (Billion USD)": 5,
        "Alternative Suppliers": "Turkey, Morocco, India",
        "Use Case Impact": "Fashion, food, agriculture"
    },
    {
        "Country": "Bangladesh",
        "Tariff Imposed by US (%)": 37,  # Updated from 15%; AS USA and The Daily Star report 37%
        "Top Product Categories": "Apparel, Textiles, Seafood",
        "Specific Product Names": "Walmart tees, jute bags, shrimp",
        "Estimated Annual Import Value (Billion USD)": 4,
        "Alternative Suppliers": "Vietnam, India, Pakistan",
        "Use Case Impact": "Clothing, packaging, food"
    },
    {
        "Country": "Peru",
        "Tariff Imposed by US (%)": 10,  # Updated from 0%; 10% baseline tariff (AS USA, Hindustan Times)
        "Top Product Categories": "Copper, Agricultural Products, Textiles",
        "Specific Product Names": "Copper wire, asparagus, alpaca sweaters",
        "Estimated Annual Import Value (Billion USD)": 3,
        "Alternative Suppliers": "Chile, Bolivia, Mexico",
        "Use Case Impact": "Electronics, food, fashion"
    },
    {
        "Country": "Morocco",
        "Tariff Imposed by US (%)": 10,  # Updated from 0%; 10% baseline tariff (Middle East Eye, Hindustan Times)
        "Top Product Categories": "Textiles, Agricultural Products, Phosphates",
        "Specific Product Names": "Cotton scarves, oranges, fertilizers",
        "Estimated Annual Import Value (Billion USD)": 2.5,
        "Alternative Suppliers": "Egypt, Tunisia, Spain",
        "Use Case Impact": "Fashion, food, agriculture"
    },
    {
        "Country": "Ecuador",
        "Tariff Imposed by US (%)": 10,  # Updated from 2%; 10% baseline tariff (AS USA, Hindustan Times)
        "Top Product Categories": "Oil, Seafood, Flowers",
        "Specific Product Names": "Crude oil, shrimp, roses",
        "Estimated Annual Import Value (Billion USD)": 2,
        "Alternative Suppliers": "Colombia, Peru, Venezuela",
        "Use Case Impact": "Energy, food, floral industry"
    },
    {
        "Country": "Ukraine",
        "Tariff Imposed by US (%)": 10,  # Updated from 2%; 10% baseline tariff (TIME, AS USA)
        "Top Product Categories": "Steel, Agricultural Products, Chemicals",
        "Specific Product Names": "Rebar, sunflower oil, fertilizers",
        "Estimated Annual Import Value (Billion USD)": 1.5,
        "Alternative Suppliers": "Russia, Turkey, Poland",
        "Use Case Impact": "Construction, food, agriculture"
    }
]



# Create DataFrame
df = pd.DataFrame(data)

df.to_csv("data.csv", index=False)
