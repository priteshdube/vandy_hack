# %%
import pandas as pd

# Define enhanced dataset
data = [
    {
        "Country": "China",
        "Tariff Imposed by US (%)": 54,
        "Top Product Categories": "Electronics, Apparel, Toys",
        "Specific Product Names": "Apple iPhones, Lenovo laptops, Nike shoes, Mattel toys",
        "Estimated Annual Import Value (Billion USD)": 500,
        "Alternative Suppliers": "Vietnam, South Korea, India",
        "Use Case Impact": "Consumer electronics, daily clothing, children's goods"
    },
    {
        "Country": "Mexico",
        "Tariff Imposed by US (%)": 25,
        "Top Product Categories": "Vehicles, Machinery, Agricultural Products",
        "Specific Product Names": "General Motors cars, Caterpillar machinery, Avocados",
        "Estimated Annual Import Value (Billion USD)": 400,
        "Alternative Suppliers": "Brazil, Canada",
        "Use Case Impact": "Transportation, construction, food prices"
    },
    {
        "Country": "Canada",
        "Tariff Imposed by US (%)": 25,
        "Top Product Categories": "Energy Resources, Vehicles, Machinery",
        "Specific Product Names": "Crude oil, Ford cars, John Deere equipment",
        "Estimated Annual Import Value (Billion USD)": 350,
        "Alternative Suppliers": "Saudi Arabia, Mexico",
        "Use Case Impact": "Fuel prices, farming, transportation"
    },
    {
        "Country": "Japan",
        "Tariff Imposed by US (%)": 34,
        "Top Product Categories": "Automobiles, Electronics, Machinery",
        "Specific Product Names": "Toyota Camry, Sony electronics, Hitachi excavators",
        "Estimated Annual Import Value (Billion USD)": 200,
        "Alternative Suppliers": "South Korea, Germany",
        "Use Case Impact": "Car prices, industrial electronics"
    },
    {
        "Country": "Germany",
        "Tariff Imposed by US (%)": 30,
        "Top Product Categories": "Automobiles, Pharmaceuticals, Machinery",
        "Specific Product Names": "BMW 3 Series, Bayer medications, Siemens turbines",
        "Estimated Annual Import Value (Billion USD)": 180,
        "Alternative Suppliers": "Japan, UK",
        "Use Case Impact": "Luxury vehicles, medications, infrastructure"
    },
    {
        "Country": "India",
        "Tariff Imposed by US (%)": 36,
        "Top Product Categories": "Pharmaceuticals, Textiles, Software Services",
        "Specific Product Names": "Generic drugs, Cotton garments, Infosys software",
        "Estimated Annual Import Value (Billion USD)": 150,
        "Alternative Suppliers": "Bangladesh, Vietnam",
        "Use Case Impact": "Healthcare affordability, clothing"
    },
    {
        "Country": "South Korea",
        "Tariff Imposed by US (%)": 35,
        "Top Product Categories": "Electronics, Automobiles, Semiconductors",
        "Specific Product Names": "Samsung phones, Hyundai cars, SK Hynix chips",
        "Estimated Annual Import Value (Billion USD)": 170,
        "Alternative Suppliers": "Taiwan, Japan",
        "Use Case Impact": "Smartphone and car costs"
    },
    {
        "Country": "Vietnam",
        "Tariff Imposed by US (%)": 56,
        "Top Product Categories": "Clothing, Electronics, Footwear",
        "Specific Product Names": "Nike apparel, LG TVs, Adidas sneakers",
        "Estimated Annual Import Value (Billion USD)": 120,
        "Alternative Suppliers": "Bangladesh, China",
        "Use Case Impact": "Retail clothing and home electronics"
    },
    {
        "Country": "Taiwan",
        "Tariff Imposed by US (%)": 42,
        "Top Product Categories": "Semiconductors, Machinery, Electronics",
        "Specific Product Names": "TSMC chips, ASUS laptops, Foxconn components",
        "Estimated Annual Import Value (Billion USD)": 100,
        "Alternative Suppliers": "South Korea, USA (Intel)",
        "Use Case Impact": "Tech manufacturing and consumer devices"
    },
    {
        "Country": "Thailand",
        "Tariff Imposed by US (%)": 46,
        "Top Product Categories": "Automotive parts, Electronics, Rubber",
        "Specific Product Names": "Honda car parts, Sharp TVs, Latex gloves",
        "Estimated Annual Import Value (Billion USD)": 90,
        "Alternative Suppliers": "Malaysia, Indonesia",
        "Use Case Impact": "Automobile maintenance, healthcare supplies"
    }
]

# Create DataFrame
data = pd.DataFrame(data)

df.to_csv("data.csv", index=False)
